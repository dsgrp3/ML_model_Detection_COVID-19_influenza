# %% [markdown]
# ## Appendix: Python codes and outputs

# %% [markdown]
# # Machine Learning Algorithms for COVID-19 cases Prediction

# %% [markdown]
# ## Step 1: Import Python Libraries

# %%
pip install scikit-learn
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading required libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 2: Reading Dataset

# %%
ILIdata = pd.read_csv(r"T:\my download BAG\ILIdata.csv")

ILIdata.head()
# Out:
#       Sex    Age Cough Temprature Headache Skin_rash runny_nose sorthroat  \
# 0  Female  35.00    No         No       No        No         No        No
# 1  Female  55.00   Yes        Yes      Yes        No         No        No
# 2    Male   0.75   Yes         No       No        No         No        No
# 3    Male  30.00   Yes        Yes      Yes        No         No        No
# 4  Female   3.00   Yes         No       No        No         No        No
#
#   Hemoptysis Breathing Arthritis Vomiting Covid_19_result
# 0         No        No        No       No        Negative
# 1         No       Yes        No       No        Negative
# 2         No       Yes        No       No        Positive
# 3         No       Yes       Yes       No        Negative
# 4         No        No        No       No        Positive

# %% [markdown]
# ## Step 3: Analyzing the Data

# %% [markdown]
# ## Explanatory Data Analysis

# %%
ILIdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              2001 non-null   object
#  1   Age              2001 non-null   float64
#  2   Cough            2001 non-null   object
#  3   Temprature       2001 non-null   object
#  4   Headache         2001 non-null   object
#  5   Skin_rash        2001 non-null   object
#  6   runny_nose       2001 non-null   object
#  7   sorthroat        2001 non-null   object
#  8   Hemoptysis       2001 non-null   object
#  9   Breathing        2001 non-null   object
#  10  Arthritis        2001 non-null   object
#  11  Vomiting         2001 non-null   object
#  12  Covid_19_result  2001 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 203.4+ KB

# %% [markdown]
# ### Check for Duplication

# %%
ILIdata.nunique()
# Out:
# Sex                  2
# Age                164
# Cough                2
# Temprature           2
# Headache             2
# Skin_rash            2
# runny_nose           2
# sorthroat            2
# Hemoptysis           2
# Breathing            2
# Arthritis            2
# Vomiting             2
# Covid_19_result      2
# dtype: int64

# %% [markdown]
# ### Missing Values Calculation

# %%
ILIdata.isnull().sum()
# Out:
# Sex                0
# Age                0
# Cough              0
# Temprature         0
# Headache           0
# Skin_rash          0
# runny_nose         0
# sorthroat          0
# Hemoptysis         0
# Breathing          0
# Arthritis          0
# Vomiting           0
# Covid_19_result    0
# dtype: int64

# %% [markdown]
# ## Step 4: Feature Engineering

# %%
ILIdata['Sex_n']=pd.factorize(ILIdata.Sex)[0]
ILIdata['Cough_n']=pd.factorize(ILIdata.Cough)[0]
ILIdata['Temprature_n']=pd.factorize(ILIdata.Temprature)[0]
ILIdata['Headache_n']=pd.factorize(ILIdata.Headache)[0]
ILIdata['Skin_rash_n']=pd.factorize(ILIdata.Skin_rash)[0]
ILIdata['runny_nose_n']=pd.factorize(ILIdata.runny_nose)[0]
ILIdata['sorthroat_n']=pd.factorize(ILIdata.sorthroat)[0]
ILIdata['Hemoptysis_n']=pd.factorize(ILIdata.Hemoptysis)[0]
ILIdata['Breathing_n']=pd.factorize(ILIdata.Breathing)[0]
ILIdata['Arthritis_n']=pd.factorize(ILIdata.Arthritis)[0]
ILIdata['Vomiting_n']=pd.factorize(ILIdata.Vomiting)[0]
ILIdata['Covid_19_result_n']=pd.factorize(ILIdata.Covid_19_result)[0]
ILIdata.head()
# Out:
#       Sex    Age Cough Temprature Headache Skin_rash runny_nose sorthroat  \
# 0  Female  35.00    No         No       No        No         No        No
# 1  Female  55.00   Yes        Yes      Yes        No         No        No
# 2    Male   0.75   Yes         No       No        No         No        No
# 3    Male  30.00   Yes        Yes      Yes        No         No        No
# 4  Female   3.00   Yes         No       No        No         No        No
#
#   Hemoptysis Breathing  ... Temprature_n Headache_n Skin_rash_n  runny_nose_n  \
# 0         No        No  ...            0          0           0             0
# 1         No       Yes  ...            1          1           0             0
# 2         No       Yes  ...            0          0           0             0
# 3         No       Yes  ...            1          1           0             0
# 4         No        No  ...            0          0           0             0
#
# ...

# %%
ILIdata.tail()
# Out:
#          Sex    Age Cough Temprature Headache Skin_rash runny_nose sorthroat  \
# 1996    Male   5.00   Yes        Yes      Yes        No         No        No
# 1997  Female   0.33   Yes         No       No        No         No        No
# 1998    Male   2.50   Yes         No       No        No         No       Yes
# 1999  Female  10.00   Yes        Yes      Yes        No         No        No
# 2000    Male   2.00   Yes         No       No        No         No        No
#
#      Hemoptysis Breathing  ... Temprature_n Headache_n Skin_rash_n  \
# 1996         No        No  ...            1          1           0
# 1997         No       Yes  ...            0          0           0
# 1998         No       Yes  ...            0          0           0
# 1999         No       Yes  ...            1          1           0
# 2000         No        No  ...            0          0           0
#
#       runny_nose_n  sorthroat_n  Hemoptysis_n  Breathing_n  Arthritis_n  \
# ...

# %%
ILIdata.head()
# Out:
#       Sex    Age Cough Temprature Headache Skin_rash runny_nose sorthroat  \
# 0  Female  35.00    No         No       No        No         No        No
# 1  Female  55.00   Yes        Yes      Yes        No         No        No
# 2    Male   0.75   Yes         No       No        No         No        No
# 3    Male  30.00   Yes        Yes      Yes        No         No        No
# 4  Female   3.00   Yes         No       No        No         No        No
#
#   Hemoptysis Breathing  ... Temprature_n Headache_n Skin_rash_n  runny_nose_n  \
# 0         No        No  ...            0          0           0             0
# 1         No       Yes  ...            1          1           0             0
# 2         No       Yes  ...            0          0           0             0
# 3         No       Yes  ...            1          1           0             0
# 4         No        No  ...            0          0           0             0
#
# ...

# %% [markdown]
# ### Step 5: Data Reduction

# %%
# Remove Non-numerical (object) features column from data
ILIdata = ILIdata.drop(columns=['Sex','Cough',
                                'Temprature',
                                'Headache',
                                'Skin_rash',
                                'runny_nose',
                                'sorthroat',
                                'Hemoptysis',
                                'Breathing',
                                'Arthritis',
                                'Vomiting',
                                'Covid_19_result'], axis = 1)

# %%
ILIdata.info()
ILIdata.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                2001 non-null   float64
#  1   Sex_n              2001 non-null   int64
#  2   Cough_n            2001 non-null   int64
#  3   Temprature_n       2001 non-null   int64
#  4   Headache_n         2001 non-null   int64
#  5   Skin_rash_n        2001 non-null   int64
#  6   runny_nose_n       2001 non-null   int64
#  7   sorthroat_n        2001 non-null   int64
#  8   Hemoptysis_n       2001 non-null   int64
#  9   Breathing_n        2001 non-null   int64
#  10  Arthritis_n        2001 non-null   int64
#  11  Vomiting_n         2001 non-null   int64
#  12  Covid_19_result_n  2001 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 203.4 KB
#      Age  Sex_n  Cough_n  Temprature_n  Headache_n  Skin_rash_n  runny_nose_n  \
# ...

# %% [markdown]
# ## Statistics Summary

# %%
# Describe the 'Age' column
print(ILIdata['Age'].describe())
# Out:
# count    2001.000000
# mean       13.255552
# std        21.264744
# min         0.083333
# 25%         0.750000
# 50%         2.000000
# 75%        16.000000
# max        92.000000
# Name: Age, dtype: float64

# %%
flo_cols=ILIdata.select_dtypes(include=['float64']).columns
print("Float Variables:")
print(flo_cols)
# Out:
# Float Variables:
# Index(['Age'], dtype='object')

# %%
for col in flo_cols:
    print(col)
    print('Skew :', round(ILIdata[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    ILIdata[col].hist(grid=False)
    plt.ylabel('count')
    plt.title('Patients Age Histogram plot')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=ILIdata[col])
    plt.title('Patients Age Box plot')
   # plt.subplot(1,2,3)
    #stats.probplot(x=ILIdata[col], dist='norm', plot=plt)
    #plt.title('Age QQ Plot')
    plt.show()
# Out:
# Age
# Skew : 1.72

# %%
fig, axes = plt.subplots(4, 3, figsize = (18, 30))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Sex_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Sex_n'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Cough_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Cough_n'].value_counts().index);
sns.countplot(ax = axes[0, 2], x = 'Temprature_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Temprature_n'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Headache_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Headache_n'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Skin_rash_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Skin_rash_n'].value_counts().index);
sns.countplot(ax = axes[1, 2], x = 'runny_nose_n', data = ILIdata, color = 'blue', 
              order = ILIdata['runny_nose_n'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'sorthroat_n', data = ILIdata, color = 'blue', 
              order = ILIdata['sorthroat_n'].value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Hemoptysis_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Hemoptysis_n'].value_counts().index);
sns.countplot(ax = axes[2, 2], x = 'Breathing_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Breathing_n'].value_counts().index);
sns.countplot(ax = axes[3, 0], x = 'Arthritis_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Arthritis_n'].value_counts().index);
sns.countplot(ax = axes[3, 1], x = 'Vomiting_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Vomiting_n'].value_counts().index);
sns.countplot(ax = axes[3, 2], x = 'Covid_19_result_n', data = ILIdata, color = 'blue', 
              order = ILIdata['Covid_19_result_n'].value_counts().index);

# %%
ILIdata.columns
# Out:
# Index(['Age', 'Sex_n', 'Cough_n', 'Temprature_n', 'Headache_n', 'Skin_rash_n',
#        'runny_nose_n', 'sorthroat_n', 'Hemoptysis_n', 'Breathing_n',
#        'Arthritis_n', 'Vomiting_n', 'Covid_19_result_n'],
#       dtype='object')

# %%
Feature=['Sex_n', 'Cough_n', 'Temprature_n', 'Headache_n', 'Skin_rash_n',
       'runny_nose_n', 'sorthroat_n', 'Hemoptysis_n', 'Breathing_n',
       'Arthritis_n', 'Vomiting_n']

# %%
list(enumerate(Feature))
# Out:
# [(0, 'Sex_n'),
#  (1, 'Cough_n'),
#  (2, 'Temprature_n'),
#  (3, 'Headache_n'),
#  (4, 'Skin_rash_n'),
#  (5, 'runny_nose_n'),
#  (6, 'sorthroat_n'),
#  (7, 'Hemoptysis_n'),
#  (8, 'Breathing_n'),
#  (9, 'Arthritis_n'),
#  (10, 'Vomiting_n')]

# %%
plt.figure(figsize=(18,30))
for i, feature in enumerate(Feature):
    plt.subplot(4, 3, i + 1)
    sns.countplot(x=feature, hue='Covid_19_result_n', data=ILIdata)

# %% [markdown]
# ## Splitting the Data-Set into Training Set and Test Set

# %%
#define X variables and our target(y)
x = ILIdata.drop(['Covid_19_result_n'],axis=1).values  
y = ILIdata['Covid_19_result_n'].values

# %%
scaled_dataX=StandardScaler().fit_transform(x)
scaled_dataX
# Out:
# array([[ 1.02281425, -1.09825962, -3.35798654, ..., -1.78991103,
#         -0.14282071, -0.44035677],
#        [ 1.96357324, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.58823553,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        ...,
#        [-0.50591912,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071,  2.27088597],
#        [-0.15313449, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.52943809,  0.91053152,  0.2977975 , ..., -1.78991103,
#         -0.14282071, -0.44035677]])

# %% [markdown]
# ## Standardize features

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'x' is the data you want to scale (make sure x is defined somewhere)
scaler = StandardScaler()
scaled_dataX = scaler.fit_transform(x)

# Display the scaled data
print(scaled_dataX)
# Out:
# [[ 1.02281425 -1.09825962 -3.35798654 ... -1.78991103 -0.14282071
#   -0.44035677]
#  [ 1.96357324 -1.09825962  0.2977975  ...  0.55868699 -0.14282071
#   -0.44035677]
#  [-0.58823553  0.91053152  0.2977975  ...  0.55868699 -0.14282071
#   -0.44035677]
#  ...
#  [-0.50591912  0.91053152  0.2977975  ...  0.55868699 -0.14282071
#    2.27088597]
#  [-0.15313449 -1.09825962  0.2977975  ...  0.55868699 -0.14282071
#   -0.44035677]
#  [-0.52943809  0.91053152  0.2977975  ... -1.78991103 -0.14282071
#   -0.44035677]]

# %%
scaled_dataX=StandardScaler().fit_transform(x)
scaled_dataX
# Out:
# array([[ 1.02281425, -1.09825962, -3.35798654, ..., -1.78991103,
#         -0.14282071, -0.44035677],
#        [ 1.96357324, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.58823553,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        ...,
#        [-0.50591912,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071,  2.27088597],
#        [-0.15313449, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.52943809,  0.91053152,  0.2977975 , ..., -1.78991103,
#         -0.14282071, -0.44035677]])

# %%
#split Train and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_dataX, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Random Forest ML model

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(X_test)

# %%
#Let’s test the performance of our model – roc_auc curve
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("roc_auc : ", roc_auc)
# Out:
# roc_auc :  0.8300541358635543

# %%
#Let’s test the performance of our model – Confusion Matrix
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_test, y_pred) 
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[389  30]
#  [ 22  60]]

# %% [markdown]
# ## More Model evaluation metrics

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label=1)
recall = recall_score(y_test, y_pred, pos_label=1)
f1 = f1_score(y_test, y_pred, pos_label=1)

# Print the model performance metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.8962075848303394
# Precision: 0.6666666666666666
# Recall: 0.7317073170731707
# F1 Score: 0.6976744186046512

# %% [markdown]
# ## Support Vector Machine Algorithm

# %%
#define X variables and our target(y)
xs = ILIdata.drop(['Covid_19_result_n'],axis=1).values  
ys = ILIdata['Covid_19_result_n'].values

# %% [markdown]
# ## Standardize features

# %%
scaled_dataXs=StandardScaler().fit_transform(xs)
scaled_dataXs
# Out:
# array([[ 1.02281425, -1.09825962, -3.35798654, ..., -1.78991103,
#         -0.14282071, -0.44035677],
#        [ 1.96357324, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.58823553,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        ...,
#        [-0.50591912,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071,  2.27088597],
#        [-0.15313449, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.52943809,  0.91053152,  0.2977975 , ..., -1.78991103,
#         -0.14282071, -0.44035677]])

# %%
#split Train and Test
from sklearn.model_selection import train_test_split
X_trains, X_tests, y_trains, y_tests = train_test_split(scaled_dataXs, ys, test_size=0.25, random_state=24)

# %%
X_trains.shape
# Out:
# (1500, 12)

# %%
from sklearn.svm import SVC

# %%
sv=SVC()
sv.fit(X_trains,y_trains)
# Out:
# SVC()

# %%
sv_pred=sv.predict(X_tests)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_tests, sv_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
print("roc_auc : ", roc_auc)
# Out:
# roc_auc :  0.8744187173028483

# %%
from sklearn.metrics import roc_curve, auc

# %%
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_tests, sv_pred) 
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[366  31]
#  [ 18  86]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_tests, y_pred)
precision = precision_score(y_tests, sv_pred, pos_label=1)
recall = recall_score(y_tests, sv_pred, pos_label=1)
f1 = f1_score(y_tests, sv_pred, pos_label=1)

# Print the model performance metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.6926147704590818
# Precision: 0.7350427350427351
# Recall: 0.8269230769230769
# F1 Score: 0.7782805429864253

# %% [markdown]
# ## Decision Tree Classification machine learning Algorism

# %%
#define X variables and our target(y)
xd = ILIdata.drop(['Covid_19_result_n'],axis=1).values  
yd = ILIdata['Covid_19_result_n'].values

# %%
scaled_dataXd=StandardScaler().fit_transform(xd)
scaled_dataXd
# Out:
# array([[ 1.02281425, -1.09825962, -3.35798654, ..., -1.78991103,
#         -0.14282071, -0.44035677],
#        [ 1.96357324, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.58823553,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        ...,
#        [-0.50591912,  0.91053152,  0.2977975 , ...,  0.55868699,
#         -0.14282071,  2.27088597],
#        [-0.15313449, -1.09825962,  0.2977975 , ...,  0.55868699,
#         -0.14282071, -0.44035677],
#        [-0.52943809,  0.91053152,  0.2977975 , ..., -1.78991103,
#         -0.14282071, -0.44035677]])

# %%
#split Train and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_dataXd, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'data' is your original dataset and 'X' is your feature set
scaler = StandardScaler()
scaled_dataXd = scaler.fit_transform(xs)  # Replace X with your actual feature set

# %%
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier(criterion='gini',
                          max_depth=7,
                          min_samples_split=9,
                          random_state=10)

# %%
DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, min_samples_split=9, random_state=10)

# %%
yd_pred=DTC.predict(X_test)

# %%
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, yd_pred)
auc_DT = auc(false_positive_rate, true_positive_rate)

print("roc_auc : ", roc_auc)
# Out:
# roc_auc :  0.8744187173028483

# %%
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_test, yd_pred) 
print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[397  22]
#  [ 26  56]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, yd_pred)
precision = precision_score(y_test, yd_pred, pos_label=1)
recall = recall_score(y_test, yd_pred, pos_label=1)
f1 = f1_score(y_test, yd_pred, pos_label=1)
# Print the model performance metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9041916167664671
# Precision: 0.717948717948718
# Recall: 0.6829268292682927
# F1 Score: 0.7

# %%
sv_predau=sv.decision_function(X_tests)

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rateRF, true_positive_rateRF, thresholds = roc_curve(y_test, y_pred)
auc_RF = auc(false_positive_rateRF, true_positive_rateRF)

false_positive_rateDT, true_positive_rateDT, thresholds = roc_curve(y_test, yd_pred)
auc_DT = auc(false_positive_rateDT, true_positive_rateDT)

svm_fpr,svm_tpr, thresholds = roc_curve(y_tests, sv_predau)
auc_svm = auc(svm_fpr, svm_tpr)

plt.figure(figsize=(5,5), dpi=120)
plt.plot(false_positive_rateRF, true_positive_rateRF, linestyle='-', label='RF (auc=%0.3f)' %auc_RF)
plt.plot(false_positive_rateDT, true_positive_rateDT, linestyle='-', label='DT (auc=%0.3f)' %auc_DT)
plt.plot(svm_fpr, svm_tpr, linestyle='-', label='SVM (auc=%0.3f)' %auc_svm)


plt.xlabel('False positive rate')
plt.ylabel('True positive rate')

plt.legend()
plt.show()

# %%
df = pd.DataFrame(ILIdata)

# %%
df.corr()
# Out:
#                         Age     Sex_n   Cough_n  Temprature_n  Headache_n  \
# Age                1.000000 -0.082564 -0.006347      0.056321    0.359681
# Sex_n             -0.082564  1.000000 -0.014253     -0.018076   -0.004832
# Cough_n           -0.006347 -0.014253  1.000000      0.163163    0.027854
# Temprature_n       0.056321 -0.018076  0.163163      1.000000    0.226125
# Headache_n         0.359681 -0.004832  0.027854      0.226125    1.000000
# Skin_rash_n        0.018785 -0.003242  0.015771     -0.025379    0.059850
# runny_nose_n      -0.130460 -0.011335 -0.112929      0.083012   -0.032089
# sorthroat_n        0.056346 -0.015932  0.059731      0.086533    0.210630
# Hemoptysis_n       0.129484 -0.016096  0.009872      0.012858    0.112571
# Breathing_n       -0.035090  0.024148 -0.110595     -0.287159   -0.032419
# Arthritis_n        0.141074  0.008112  0.016426      0.201358    0.255547
# Vomiting_n        -0.144673  0.025350  0.096463      0.022387   -0.033387
# ...

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',linewidths=0.4)
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# #Compare Models

# %%
#Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR  # Import Support Vector Regressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
#initialize models

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Support Vector Regressor": SVR()  # SVM Regressor added here
}

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR  # Import Support Vector Regressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Load your dataset (replace 'your_data.csv' with your actual file)
# data = pd.read_csv('your_data.csv')

# Assuming 'X' is your feature matrix and 'y' is your target variable
# X = data.drop('target_column', axis=1)
# y = data['target_column']

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


# Initialize models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Support Vector Regressor": SVR()  # SVM Regressor added here
}

# Train and evaluate each model
for name, model in models.items():
    # Train the model
    model.fit(x_train, y_train)
    
    # Make predictions
    y_pred = model.predict(x_test)
    
    # Calculate metrics
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    
    # Print results
    print(f"{name}:")
    print(f"Mean Absolute Error: {mae}")
    print(f"Mean Squared Error: {mse}")
    print(f"Root Mean Squared Error: {rmse}")
    print("-" * 30)
# Out:
# Linear Regression:
# Mean Absolute Error: 0.1284425990559099
# Mean Squared Error: 0.05906551853146223
# Root Mean Squared Error: 0.24303398637117038
# ------------------------------
# Decision Tree Regressor:
# Mean Absolute Error: 0.125347345920912
# Mean Squared Error: 0.11076898174065967
# Root Mean Squared Error: 0.33281974361605965
# ------------------------------
# Random Forest Regressor:
# Mean Absolute Error: 0.13235861633416798
# Mean Squared Error: 0.07701432463298817
# Root Mean Squared Error: 0.27751454850689933
# ------------------------------
# Support Vector Regressor:
# Mean Absolute Error: 0.20501281788957776
# Mean Squared Error: 0.08814933617552946
# Root Mean Squared Error: 0.29689953886041903
# ------------------------------

# %%
# !pip install pycaret

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pycaret.regression import *
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pycaret\__init__.py:22
#      16     raise RuntimeError(
#      17         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      18         sys.version_info,
#      19         "Please UPGRADE your Python version.",
#      20     )
#      21 elif sys.version_info >= (3, 12):
# ---> 22     raise RuntimeError(
#      23         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      24         sys.version_info,
#      25         "Please DOWNGRADE your Python version.",
#      26     )
#
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numba
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas-profiling
# Out:
# ...
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pycaret 3.3.2 requires joblib<1.4,>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# scikit-learn 1.4.2 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# ydata-profiling 4.12.0 requires visions[type_image_path]<0.7.7,>=0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
pip install pandas joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numba==0.56.4
# Out:
# ...
#   Using cached numba-0.56.4.tar.gz (2.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [10 lines of output]
#   C:\Users\teklu\AppData\Local\Temp\pip-install-3tvnfysh\numba_44f71adab9e14f01a77ac79c6fde1e6f\versioneer.py:335: SyntaxWarning: invalid escape sequence '\s'
#     LONG_VERSION_PY['git'] = '''
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\teklu\AppData\Local\Temp\pip-install-3tvnfysh\numba_44f71adab9e14f01a77ac79c6fde1e6f\setup.py", line 51, in <module>
#       _guard_py_ver()
# ...

# %%
pip show pandas-profiling
# Out:
# Name: pandas-profiling
# Version: 3.2.0
# Summary: Generate profile report for pandas DataFrame
# Home-page: https://github.com/pandas-profiling/pandas-profiling
# Author: Simon Brugman
# Author-email: pandasprofiling@gmail.com
# License: MIT
# Location: C:\Users\teklu\anaconda3\Lib\site-packages
# Requires: htmlmin, jinja2, joblib, markupsafe, matplotlib, missingno, multimethod, numpy, pandas, phik, pydantic, PyYAML, requests, scipy, seaborn, tangled-up-in-unicode, tqdm, visions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.regression import*
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import profileReport
import Warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from pycaret.regression import*
#       2 import pandas as pd
#       3 import seaborn as sns
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pycaret\__init__.py:22
#      16     raise RuntimeError(
#      17         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      18         sys.version_info,
#      19         "Please UPGRADE your Python version.",
#      20     )
#      21 elif sys.version_info >= (3, 12):
# ---> 22     raise RuntimeError(
#      23         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      24         sys.version_info,
#      25         "Please DOWNGRADE your Python version.",
#      26     )
#
# ...

# %%
pip install --upgrade pandas-profiling
# Out:
# ...
#
# ...

# %%
pip show pandas-profiling
# Out:
# Name: pandas-profiling
# Version: 3.2.0
# Summary: Generate profile report for pandas DataFrame
# Home-page: https://github.com/pandas-profiling/pandas-profiling
# Author: Simon Brugman
# Author-email: pandasprofiling@gmail.com
# License: MIT
# Location: C:\Users\teklu\anaconda3\Lib\site-packages
# Requires: htmlmin, jinja2, joblib, markupsafe, matplotlib, missingno, multimethod, numpy, pandas, phik, pydantic, PyYAML, requests, scipy, seaborn, tangled-up-in-unicode, tqdm, visions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show numba
# Out:
# Name: numba
# Version: 0.60.0
# Summary: compiling Python code using LLVM
# Home-page: https://numba.pydata.org
# Author:
# Author-email:
# License: BSD
# Location: C:\Users\teklu\anaconda3\Lib\site-packages
# Requires: llvmlite, numpy
# Required-by: datashader, pycaret, pyod
# Note: you may need to restart the kernel to use updated packages.

# %%
#profileReport(df)

# %%
pip install --upgrade pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numba
# Out:
# ...
#
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # create the DataFrame that serves as the input for PyCaret.
# import pandas as pd
#
# # Correct method to read a CSV file
# df = pd.read_csv(r"T:\my download BAG\ILIdata.csv")
#
# # Display the first few rows of the dataframe
# df.head()

# %%
import pandas as pd

# Correct method to read a CSV file
df = pd.read_csv(r"T:\my download BAG\ILIdata.csv")

# Display the first few rows of the dataframe
df.head()
# Out:
#       Sex    Age Cough Temprature Headache Skin_rash runny_nose sorthroat  \
# 0  Female  35.00    No         No       No        No         No        No
# 1  Female  55.00   Yes        Yes      Yes        No         No        No
# 2    Male   0.75   Yes         No       No        No         No        No
# 3    Male  30.00   Yes        Yes      Yes        No         No        No
# 4  Female   3.00   Yes         No       No        No         No        No
#
#   Hemoptysis Breathing Arthritis Vomiting Covid_19_result
# 0         No        No        No       No        Negative
# 1         No       Yes        No       No        Negative
# 2         No       Yes        No       No        Positive
# 3         No       Yes       Yes       No        Negative
# 4         No        No        No       No        Positive

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001 entries, 0 to 2000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sex              2001 non-null   object
#  1   Age              2001 non-null   float64
#  2   Cough            2001 non-null   object
#  3   Temprature       2001 non-null   object
#  4   Headache         2001 non-null   object
#  5   Skin_rash        2001 non-null   object
#  6   runny_nose       2001 non-null   object
#  7   sorthroat        2001 non-null   object
#  8   Hemoptysis       2001 non-null   object
#  9   Breathing        2001 non-null   object
#  10  Arthritis        2001 non-null   object
#  11  Vomiting         2001 non-null   object
#  12  Covid_19_result  2001 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 203.4+ KB

# %%
# pass the DataFrame to PyCaret's setup() function for data preprocessing

# %% [markdown]
# from ydata_profiling import ProfileReport

# %%
pip install ydata-profiling
# Out:
# ...
#   Using cached ydata_profiling-4.12.0-py2.py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached dacite-1.8.1-py3-none-any.whl.metadata (15 kB)
# ...
# Using cached ydata_profiling-4.12.0-py2.py3-none-any.whl (390 kB)
# Using cached dacite-1.8.1-py3-none-any.whl (14 kB)
# Using cached typeguard-4.4.1-py3-none-any.whl (35 kB)
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from ydata_profiling import ProfileReport

# %%
from pycaret.classification import setup, compare_models


# Set up PyCaret environment
clf = setup(data=df, target='Covid_19_result')

# Compare models
best_model = compare_models()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycaret.classification import setup, compare_models
#       4 # Set up PyCaret environment
#       5 clf = setup(data=df, target='Covid_19_result')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pycaret\__init__.py:22
#      16     raise RuntimeError(
#      17         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      18         sys.version_info,
#      19         "Please UPGRADE your Python version.",
#      20     )
#      21 elif sys.version_info >= (3, 12):
# ---> 22     raise RuntimeError(
#      23         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      24         sys.version_info,
#      25         "Please DOWNGRADE your Python version.",
#      26     )
#
# ...

# %%
# Data visualization-install profiling

# %%
# !pip install pandas_profiling
# Out:
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.6
#     Uninstalling visions-0.7.6:
#       Successfully uninstalled visions-0.7.6
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.12.0 requires visions[type_image_path]<0.7.7,>=0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
ProfileReport(df)

# %%
pip install pycaret

# %%
from pycaret.classification import *

# %% [markdown]
# # Setup PyCaret Environment Before calling plot_model

# %%
from pycaret.regression import*
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import profileReport
import Warnings
warnings.filterwarnings('ignore')

# %%
pip show pycaret
# Out:
# Name: pycaret
# Version: 3.3.2
# Summary: PyCaret - An open source, low-code machine learning library in Python.
# Home-page: https://github.com/pycaret/pycaret
# Author: Moez Ali
# Author-email: moez.ali@queensu.ca
# License: MIT
# Location: C:\Users\teklu\AppData\Roaming\Python\Python312\site-packages
# Requires: category-encoders, cloudpickle, deprecation, imbalanced-learn, importlib-metadata, ipython, ipywidgets, jinja2, joblib, kaleido, lightgbm, markupsafe, matplotlib, nbformat, numba, numpy, pandas, plotly, plotly-resampler, pmdarima, psutil, pyod, requests, schemdraw, scikit-learn, scikit-plot, scipy, sktime, statsmodels, tbats, tqdm, xxhash, yellowbrick
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Plot feature importance
plot_model(model, plot='feature')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Plot feature importance
# ----> 2 plot_model(model, plot='feature')
#
# NameError: name 'plot_model' is not defined

# %% [markdown]
# # Install Dependencies: Ensure all required dependencies for PyCaret are installed

# %%
pip install -U scikit-learn pandas matplotlib seaborn
# Out:
# ...
#   Using cached scikit_learn-1.5.2-cp312-cp312-win_amd64.whl.metadata (13 kB)
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
# ...

# %%
print(data.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(data.columns)
#
# NameError: name 'data' is not defined

# %%
# Import required libraries
import pandas as pd
from pycaret.classification import *  # Use PyCaret's classification module

# Load your dataset
data_path = r"T:\my download BAG\ILIdata.csv"  # Ensure the file path is correct
data = pd.read_csv(data_path)  # Load the dataset

# Inspect the dataset (optional)
print(data.head())  # Display the first few rows of your dataset
print(data.info())  # Display information about the dataset

# Set up the PyCaret environment
# Replace 'Covid_19_result' with the actual name of your target column in the dataset
clf_setup = setup(data=data, target='Covid_19_result', verbose=False, session_id=123)

# Train a Logistic Regression model
model = create_model('rf')  # 'lr' stands for Logistic Regression
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Import required libraries
#       2 import pandas as pd
# ----> 3 from pycaret.classification import *  # Use PyCaret's classification module
#       5 # Load your dataset
#       6 data_path = r"T:\my download BAG\ILIdata.csv"  # Ensure the file path is correct
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pycaret\__init__.py:22
#      16     raise RuntimeError(
#      17         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      18         sys.version_info,
#      19         "Please UPGRADE your Python version.",
#      20     )
#      21 elif sys.version_info >= (3, 12):
# ---> 22     raise RuntimeError(
#      23         "Pycaret only supports python 3.9, 3.10, 3.11. Your actual Python version: ",
#      24         sys.version_info,
# ...

# %%
pip install --upgrade pycaret

# %%
# Train a Random Forest model
rf_model = create_model('rf')  # 'rf' stands for Random Forest
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Train a Random Forest model
# ----> 2 rf_model = create_model('rf')
#
# NameError: name 'create_model' is not defined

# %%
# Train a Support Vector Machine model
svm_model = create_model('svm')  # 'svm' stands for Support Vector Machine

# %%
# Train a Decision Tree model
dt_model = create_model('dt')  # 'dt' stands for Decision Tree

# %%
# Plot feature importance
plot_model(model, plot='feature')

# %% [markdown]
# # get coefficients

# %%
# Import required libraries
import pandas as pd
from pycaret.classification import *  # PyCaret for classification models

# Load dataset
data_path = r"T:\my download BAG\ILIdata.csv"  # Update with your file path
data = pd.read_csv(data_path)  # Ensure the file path is correct

# Set up PyCaret environment
clf_setup = setup(data=data, target='Covid_19_result', session_id=123)  # Replace with the actual target column name

# Create a Random Forest model
rf_model = create_model('rf')  # 'rf' stands for Random Forest

# Feature importance for Random Forest
importances = rf_model.feature_importances_

# Display feature importance
# Remove the target column ('Covid_19_result') from the list of columns
feature_columns = [col for col in data.columns if col != 'Covid_19_result']

# Ensure the length of feature_columns matches the length of importances
if len(feature_columns) == len(importances):
    feature_importance_df = pd.DataFrame({'Feature': feature_columns, 'Importance': importances})
    feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
    print(feature_importance_df)
else:
    print(f"Error: Mismatch in number of features and importances. {len(feature_columns)} features, {len(importances)} importances.")

# %%
# Ensure you have imported the necessary libraries
from pycaret.classification import *
import pandas as pd

# Load your dataset
data_path = r"T:\my download BAG\ILIdata.csv"  # Correct file path
data = pd.read_csv(data_path)

# Set up PyCaret environment
clf_setup = setup(data=data, target='Covid_19_result', session_id=123)

# Create a model (e.g., Logistic Regression 'lr')
model = create_model('lr')  # Replace 'lr' with the model you want to create (e.g., 'rf', 'dt')

# Check for feature names in the model
if hasattr(model, 'feature_names_in_'):
    print(model.feature_names_in_)
else:
    print("Model does not have 'feature_names_in_' attribute.")

# %%
model.feature_names_in_

# %% [markdown]
# # ziping models together

# %%
import pandas as pd

# %%
import pandas as pd

# For binary classification (Logistic Regression)
feature_names = model.feature_names_in_  # Get feature names
coefficients = model.coef_[0]  # Access the coefficients for the first class (binary)

# Create a DataFrame with feature names and their corresponding coefficients
df_coefficients = pd.DataFrame(zip(feature_names, coefficients), columns=['Features', 'Coefficients'])
print(df_coefficients)

# %%
import pandas as pd

# For binary classification (Logistic Regression)
feature_names = model.feature_names_in_  # Get feature names
coefficients = model.coef_[0]  # Access the coefficients for the first class (binary)

# Create a DataFrame with feature names and their corresponding coefficients
df_coefficients = pd.DataFrame(zip(feature_names, coefficients), columns=['Features', 'Coefficients'])
print(df_coefficients)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 import pandas as pd
#       3 # For binary classification (Logistic Regression)
# ----> 4 feature_names = model.feature_names_in_  # Get feature names
#       5 coefficients = model.coef_[0]  # Access the coefficients for the first class (binary)
#       7 # Create a DataFrame with feature names and their corresponding coefficients
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
from pycaret.classification import *  # Import pycaret for classification tasks

# Load dataset and set up PyCaret (Update with your own dataset)
data_path = r"T:\my download BAG\ILIdata.csv"  # Update with your file path
data = pd.read_csv(data_path)

# Set up the PyCaret environment (make sure 'Covid_19_result' is your target column)
clf_setup = setup(data=data, target='Covid_19_result', session_id=123)

# Create and train a Random Forest model
rf_model = create_model('rf')

# Access the feature importances (for Random Forest)
importances = rf_model.feature_importances_

# Get feature names from the PyCaret environment
# Use 'get_config' to access the dataset used in setup
feature_names = get_config('X_train').columns  # 'X_train' holds the feature data from the setup

# Create a DataFrame with feature names and their importance values
df_importances = pd.DataFrame(zip(feature_names, importances), columns=['Features', 'Importance'])

# Sort by importance and display
df_importances = df_importances.sort_values(by='Importance', ascending=False)
print(df_importances)

# %%
import pandas as pd

# Assuming `model` is a fitted model (e.g., from PyCaret or scikit-learn)
# For logistic regression, 'model.coef_' contains the coefficients
# Example: model = create_model('lr') or any fitted linear model

# Access the coefficients and feature names
coefficients = model.coef_[0]  # This is where the coefficients are stored for logistic regression
feature_names = model.feature_names_in_  # This gives you the feature names

# Create a DataFrame with feature names and their corresponding coefficients
df_coefficients = pd.DataFrame(zip(feature_names, coefficients), columns=['Features', 'coefficients'])

# Display the DataFrame
print(df_coefficients)
